# %% [markdown]
# # 04 — Few-shot: Taxonomy Classification\n
# \n
# Evaluate k-shot fine-tuning on FishNet top-100 species.\n
# \n
# Planned k values: 1, 5, 10, 20.\n
# Report mean ± std over multiple random seeds/splits.

# %%
from pathlib import Path
import sys

import numpy as np
import torch

ROOT = Path('..').resolve()
sys.path.append(str((ROOT / 'src').resolve()))

MANIFEST_DIR = (ROOT / 'data' / 'manifests').resolve()
OUT_DIR = (ROOT / 'outputs' / 'fewshot_taxonomy').resolve()
OUT_DIR.mkdir(parents=True, exist_ok=True)

device = torch.device(
    'cuda'
    if torch.cuda.is_available()
    else 'mps'
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available()
    else 'cpu'
)
print('device:', device)
print('OUT_DIR:', OUT_DIR)
# Out:
# device: cuda
# OUT_DIR: D:\Fish Codes\outputs\fewshot_taxonomy

# %%
from torch.utils.data import DataLoader

from fish_ai.data.fewshot import write_fewshot_train_manifest
from fish_ai.data.jsonl import read_jsonl
from fish_ai.data.taxonomy_dataset import FishTaxonomyDataset
from fish_ai.models.taxonomy_classifier import TaxonomyClassifier, TaxonomyHeadSizes
from fish_ai.train.taxonomy_train import TrainConfig, build_label_maps, evaluate, train_one_epoch
from fish_ai.utils.run_logging import write_csv, write_json

train_full = MANIFEST_DIR / 'fishnet_taxonomy_train.jsonl'
val_manifest = MANIFEST_DIR / 'fishnet_taxonomy_val.jsonl'
test_manifest = MANIFEST_DIR / 'fishnet_taxonomy_test.jsonl'

print(train_full.exists(), val_manifest.exists(), test_manifest.exists())
# Out:
# True True True

# %%
# Build label maps from FULL training set (keeps label space consistent across k)
train_rows = []
for r in read_jsonl(train_full):
    tax = r['taxonomy']
    train_rows.append({'family': tax['family'], 'genus': tax['genus'], 'species': tax['species']})

maps = build_label_maps(train_rows)

sizes = TaxonomyHeadSizes(
    n_family=len(maps['family']),
    n_genus=len(maps['genus']),
    n_species=len(maps['species']),
)

sizes
# Out:
# TaxonomyHeadSizes(n_family=91, n_genus=199, n_species=100)

# %%
def run_kshot(k: int, seed: int, backbone: str = 'efficientnet_b0', epochs: int = 5):
    fewshot_manifest = OUT_DIR / f'fishnet_taxonomy_train_k{k}_seed{seed}.jsonl'
    write_fewshot_train_manifest(train_full, fewshot_manifest, k=k, seed=seed)

    ds_train = FishTaxonomyDataset(fewshot_manifest, image_size=224, augment=True, max_side_before_square=512)
    ds_val = FishTaxonomyDataset(val_manifest, image_size=224, augment=False, max_side_before_square=512)
    dl_train = DataLoader(ds_train, batch_size=64, shuffle=True, num_workers=2)
    dl_val = DataLoader(ds_val, batch_size=64, shuffle=False, num_workers=2)

    model = TaxonomyClassifier(sizes, backbone=backbone, pretrained=True).to(device)
    cfg = TrainConfig(num_epochs=epochs, batch_size=64, num_workers=2, lr=3e-4)
    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)

    hist = []
    for epoch in range(cfg.num_epochs):
        tr = train_one_epoch(model, dl_train, opt, device=device, maps=maps)
        va = evaluate(model, dl_val, device=device, maps=maps)

        row = {'k': k, 'seed': seed, 'epoch': epoch + 1, **tr}
        row['val_loss_total'] = va['loss_total']
        for lvl in ['family', 'genus', 'species']:
            for key, val in va[lvl].items():
                row[f'val_{lvl}_{key}'] = val

        hist.append(row)
        print(row)

    run_dir = OUT_DIR / f'k{k}_seed{seed}'
    run_dir.mkdir(parents=True, exist_ok=True)
    torch.save(
        {
            'model_state': model.state_dict(),
            'backbone': model.backbone_name,
            'maps': maps,
            'k': k,
            'seed': seed,
        },
        run_dir / 'model.pt',
    )
    write_csv(run_dir / 'history.csv', hist)
    write_json(run_dir / 'val_metrics_last.json', va)
    return va, hist


def summarize(results):
    # results: list of (k, seed, metrics_dict)
    out = []
    for k in sorted({r[0] for r in results}):
        rows = [r for r in results if r[0] == k]
        vals = [rr[2]['species']['acc_top1'] for rr in rows]
        out.append(
            {
                'k': k,
                'n_seeds': len(vals),
                'species_acc_top1_mean': float(np.mean(vals)),
                'species_acc_top1_std': float(np.std(vals)),
            }
        )
    return out

# %%
ks = [1, 5, 10, 20]
seeds = [0, 1, 2]

results = []
for k in ks:
    for seed in seeds:
        va, hist = run_kshot(k=k, seed=seed, backbone='efficientnet_b0', epochs=5)
        results.append((k, seed, va))

summary = summarize(results)
summary
# Out:
# {'k': 1, 'seed': 0, 'epoch': 1, 'loss_total': 14.48935317993164, 'loss_family': 4.527543544769287, 'loss_genus': 5.2921106815338135, 'loss_species': 4.669699192047119, 'val_family_acc_top1': 0.009551098376313277, 'val_family_acc_top5': 0.05300859598853868, 'val_family_f1_macro': 0.005926354237415688, 'val_family_f1_weighted': 0.007553987020940342, 'val_genus_acc_top1': 0.004536771728748806, 'val_genus_acc_top5': 0.03271251193887297, 'val_genus_f1_macro': 0.003022534477587655, 'val_genus_f1_weighted': 0.004102592308120852, 'val_species_acc_top1': 0.0011938872970391596, 'val_species_acc_top5': 0.009073543457497613, 'val_species_f1_macro': 0.0008982472714901009, 'val_species_f1_weighted': 0.0019498646635445808}
# {'k': 1, 'seed': 0, 'epoch': 2, 'loss_total': 13.423853397369385, 'loss_family': 4.152007102966309, 'loss_genus': 4.930186748504639, 'loss_species': 4.341660022735596, 'val_family_acc_top1': 0.01623686723973257, 'val_family_acc_top5': 0.07091690544412607, 'val_family_f1_macro': 0.009085315780709388, 'val_family_f1_weighted': 0.011864229265817412, 'val_genus_acc_top1': 0.0054918815663801334, 'val_genus_acc_top5': 0.029847182425978988, 'val_genus_f1_macro': 0.0030138233453208866, 'val_genus_f1_weighted': 0.005222915149957709, 'val_species_acc_top1': 0.0016714422158548234, 'val_species_acc_top5': 0.011222540592168099, 'val_species_f1_macro': 0.0014581062550543227, 'val_species_f1_weighted': 0.002929320293654381}
# {'k': 1, 'seed': 0, 'epoch': 3, 'loss_total': 12.594404697418213, 'loss_family': 3.8483471870422363, 'loss_genus': 4.633458137512207, 'loss_species': 4.112599849700928, 'val_family_acc_top1': 0.024355300859598854, 'val_family_acc_top5': 0.09049665711556829, 'val_family_f1_macro': 0.010894807469147009, 'val_family_f1_weighted': 0.018927129423642053, 'val_genus_acc_top1': 0.0071633237822349575, 'val_genus_acc_top5': 0.031041069723018146, 'val_genus_f1_macro': 0.003009365797642202, 'val_genus_f1_weighted': 0.006334077306835129, 'val_species_acc_top1': 0.002387774594078319, 'val_species_acc_top5': 0.013849092645654251, 'val_species_f1_macro': 0.003832898431300738, 'val_species_f1_weighted': 0.0035074174119735665}
# {'k': 1, 'seed': 0, 'epoch': 4, 'loss_total': 11.707716464996338, 'loss_family': 3.539223074913025, 'loss_genus': 4.316195726394653, 'loss_species': 3.8522979021072388, 'val_family_acc_top1': 0.030802292263610316, 'val_family_acc_top5': 0.11986628462273162, 'val_family_f1_macro': 0.012039025196066122, 'val_family_f1_weighted': 0.022543027720302432, 'val_genus_acc_top1': 0.007402101241642789, 'val_genus_acc_top5': 0.03533906399235912, 'val_genus_f1_macro': 0.0023718276065996685, 'val_genus_f1_weighted': 0.005187255845172809, 'val_species_acc_top1': 0.004059216809933142, 'val_species_acc_top5': 0.01862464183381089, 'val_species_f1_macro': 0.005090202213810549, 'val_species_f1_weighted': 0.005457211479679328}
# {'k': 1, 'seed': 0, 'epoch': 5, 'loss_total': 10.810884475708008, 'loss_family': 3.1960396766662598, 'loss_genus': 4.009274959564209, 'loss_species': 3.605569839477539, 'val_family_acc_top1': 0.038204393505253106, 'val_family_acc_top5': 0.1353868194842407, 'val_family_f1_macro': 0.013572953664687264, 'val_family_f1_weighted': 0.024190102448419962, 'val_genus_acc_top1': 0.011461318051575931, 'val_genus_acc_top5': 0.0389207258834766, 'val_genus_f1_macro': 0.0035341013140576037, 'val_genus_f1_weighted': 0.006985370812422637, 'val_species_acc_top1': 0.004775549188156638, 'val_species_acc_top5': 0.01862464183381089, 'val_species_f1_macro': 0.006265986696608705, 'val_species_f1_weighted': 0.006457596685691996}
# {'k': 1, 'seed': 1, 'epoch': 1, 'loss_total': 14.53885555267334, 'loss_family': 4.5572121143341064, 'loss_genus': 5.319247722625732, 'loss_species': 4.66239595413208, 'val_family_acc_top1': 0.014087870105062083, 'val_family_acc_top5': 0.06375358166189111, 'val_family_f1_macro': 0.005941618270403508, 'val_family_f1_weighted': 0.011202086421794415, 'val_genus_acc_top1': 0.0052531041069723014, 'val_genus_acc_top5': 0.02650429799426934, 'val_genus_f1_macro': 0.003510941803917243, 'val_genus_f1_weighted': 0.004934292429236088, 'val_species_acc_top1': 0.004059216809933142, 'val_species_acc_top5': 0.033428844317096466, 'val_species_f1_macro': 0.004554017383938717, 'val_species_f1_weighted': 0.006780390176041207}
# {'k': 1, 'seed': 1, 'epoch': 2, 'loss_total': 13.53894329071045, 'loss_family': 4.219834327697754, 'loss_genus': 4.963436603546143, 'loss_species': 4.355672121047974, 'val_family_acc_top1': 0.021012416427889206, 'val_family_acc_top5': 0.08667621776504297, 'val_family_f1_macro': 0.009662872909305772, 'val_family_f1_weighted': 0.0180231834977271, 'val_genus_acc_top1': 0.0054918815663801334, 'val_genus_acc_top5': 0.025549188156638012, 'val_genus_f1_macro': 0.003751370707592543, 'val_genus_f1_weighted': 0.005893377130995956, 'val_species_acc_top1': 0.0052531041069723014, 'val_species_acc_top5': 0.04393505253104107, 'val_species_f1_macro': 0.0032952087286660828, 'val_species_f1_weighted': 0.008181743110178472}
# {'k': 1, 'seed': 1, 'epoch': 3, 'loss_total': 12.704412460327148, 'loss_family': 3.9331387281417847, 'loss_genus': 4.670234441757202, 'loss_species': 4.101039171218872, 'val_family_acc_top1': 0.0329512893982808, 'val_family_acc_top5': 0.11246418338108882, 'val_family_f1_macro': 0.010300405710283934, 'val_family_f1_weighted': 0.02183771594228063, 'val_genus_acc_top1': 0.0064469914040114614, 'val_genus_acc_top5': 0.02865329512893983, 'val_genus_f1_macro': 0.004391477543462514, 'val_genus_f1_weighted': 0.006224569096361104, 'val_species_acc_top1': 0.0052531041069723014, 'val_species_acc_top5': 0.0561127029608405, 'val_species_f1_macro': 0.0020077500764590413, 'val_species_f1_weighted': 0.008149728547874026}
# {'k': 1, 'seed': 1, 'epoch': 4, 'loss_total': 11.847294807434082, 'loss_family': 3.622178554534912, 'loss_genus': 4.388386487960815, 'loss_species': 3.836729645729065, 'val_family_acc_top1': 0.04632282712511939, 'val_family_acc_top5': 0.1287010506208214, 'val_family_f1_macro': 0.012643132598171902, 'val_family_f1_weighted': 0.024792866928840127, 'val_genus_acc_top1': 0.00883476599808978, 'val_genus_acc_top5': 0.032234957020057305, 'val_genus_f1_macro': 0.004654374524600782, 'val_genus_f1_weighted': 0.006382845879709784, 'val_species_acc_top1': 0.008357211079274117, 'val_species_acc_top5': 0.0651862464183381, 'val_species_f1_macro': 0.006856813488460157, 'val_species_f1_weighted': 0.01262615184652712}
# {'k': 1, 'seed': 1, 'epoch': 5, 'loss_total': 10.985663414001465, 'loss_family': 3.2868683338165283, 'loss_genus': 4.034786343574524, 'loss_species': 3.6640087366104126, 'val_family_acc_top1': 0.05348615090735435, 'val_family_acc_top5': 0.1413562559694365, 'val_family_f1_macro': 0.013393832489229464, 'val_family_f1_weighted': 0.024874243027442993, 'val_genus_acc_top1': 0.010506208213944603, 'val_genus_acc_top5': 0.03868194842406877, 'val_genus_f1_macro': 0.005107008369150305, 'val_genus_f1_weighted': 0.004743347026015276, 'val_species_acc_top1': 0.010267430754536771, 'val_species_acc_top5': 0.06566380133715377, 'val_species_f1_macro': 0.007455807583618323, 'val_species_f1_weighted': 0.01557002566653655}
# {'k': 1, 'seed': 2, 'epoch': 1, 'loss_total': 14.486924171447754, 'loss_family': 4.53856086730957, 'loss_genus': 5.298874855041504, 'loss_species': 4.649488687515259, 'val_family_acc_top1': 0.007402101241642789, 'val_family_acc_top5': 0.0494269340974212, 'val_family_f1_macro': 0.004144690133322653, 'val_family_f1_weighted': 0.006284342047112043, 'val_genus_acc_top1': 0.0028653295128939827, 'val_genus_acc_top5': 0.015281757402101241, 'val_genus_f1_macro': 0.0014242512147659035, 'val_genus_f1_weighted': 0.003206529689964473, 'val_species_acc_top1': 0.0064469914040114614, 'val_species_acc_top5': 0.03462273161413563, 'val_species_f1_macro': 0.002903701390730948, 'val_species_f1_weighted': 0.010617971532169227}
# {'k': 1, 'seed': 2, 'epoch': 2, 'loss_total': 13.525979995727539, 'loss_family': 4.20372200012207, 'loss_genus': 4.969491243362427, 'loss_species': 4.3527672290802, 'val_family_acc_top1': 0.01504297994269341, 'val_family_acc_top5': 0.06327602674307545, 'val_family_f1_macro': 0.0074034455443872885, 'val_family_f1_weighted': 0.012095726090587811, 'val_genus_acc_top1': 0.0035816618911174787, 'val_genus_acc_top5': 0.016953199617956063, 'val_genus_f1_macro': 0.002527928395209895, 'val_genus_f1_weighted': 0.004179779507130703, 'val_species_acc_top1': 0.0071633237822349575, 'val_species_acc_top5': 0.04154727793696275, 'val_species_f1_macro': 0.0020126246026033762, 'val_species_f1_weighted': 0.012924290077339562}
# {'k': 1, 'seed': 2, 'epoch': 3, 'loss_total': 12.719895362854004, 'loss_family': 3.925763487815857, 'loss_genus': 4.669444799423218, 'loss_species': 4.1246867179870605, 'val_family_acc_top1': 0.02387774594078319, 'val_family_acc_top5': 0.09145176695319962, 'val_family_f1_macro': 0.009633506696524293, 'val_family_f1_weighted': 0.017706185096357276, 'val_genus_acc_top1': 0.0038204393505253103, 'val_genus_acc_top5': 0.024116523400191024, 'val_genus_f1_macro': 0.0020616559318565393, 'val_genus_f1_weighted': 0.004070173922948175, 'val_species_acc_top1': 0.0066857688634192934, 'val_species_acc_top5': 0.04130850047755492, 'val_species_f1_macro': 0.004729922720495826, 'val_species_f1_weighted': 0.010244017115561544}
# {'k': 1, 'seed': 2, 'epoch': 4, 'loss_total': 11.788883686065674, 'loss_family': 3.6038767099380493, 'loss_genus': 4.333753347396851, 'loss_species': 3.851253628730774, 'val_family_acc_top1': 0.03127984718242598, 'val_family_acc_top5': 0.11843361986628462, 'val_family_f1_macro': 0.009146563102567696, 'val_family_f1_weighted': 0.018747835567277826, 'val_genus_acc_top1': 0.007879656160458453, 'val_genus_acc_top5': 0.029847182425978988, 'val_genus_f1_macro': 0.003159521718553666, 'val_genus_f1_weighted': 0.005262522548680279, 'val_species_acc_top1': 0.008357211079274117, 'val_species_acc_top5': 0.044890162368672396, 'val_species_f1_macro': 0.00299979301497656, 'val_species_f1_weighted': 0.013451127624781088}
# {'k': 1, 'seed': 2, 'epoch': 5, 'loss_total': 10.934625625610352, 'loss_family': 3.279181122779846, 'loss_genus': 4.0208858251571655, 'loss_species': 3.6345585584640503, 'val_family_acc_top1': 0.03772683858643744, 'val_family_acc_top5': 0.13944603629417382, 'val_family_f1_macro': 0.009558562026813188, 'val_family_f1_weighted': 0.020959695517775746, 'val_genus_acc_top1': 0.010267430754536771, 'val_genus_acc_top5': 0.034861509073543455, 'val_genus_f1_macro': 0.003616940735902086, 'val_genus_f1_weighted': 0.006109020049333408, 'val_species_acc_top1': 0.008118433619866285, 'val_species_acc_top5': 0.042263610315186245, 'val_species_f1_macro': 0.003900131795201858, 'val_species_f1_weighted': 0.01210747254353319}
# {'k': 5, 'seed': 0, 'epoch': 1, 'loss_total': 14.112914323806763, 'loss_family': 4.36684387922287, 'loss_genus': 5.160141348838806, 'loss_species': 4.585929214954376, 'val_family_acc_top1': 0.035577841451766956, 'val_family_acc_top5': 0.13729703915950334, 'val_family_f1_macro': 0.011286360045361576, 'val_family_f1_weighted': 0.02590090951740419, 'val_genus_acc_top1': 0.009073543457497613, 'val_genus_acc_top5': 0.02865329512893983, 'val_genus_f1_macro': 0.00487443581435449, 'val_genus_f1_weighted': 0.006632883256317234, 'val_species_acc_top1': 0.0064469914040114614, 'val_species_acc_top5': 0.03510028653295129, 'val_species_f1_macro': 0.0061574077760979205, 'val_species_f1_weighted': 0.008820782812367462}
# {'k': 5, 'seed': 0, 'epoch': 2, 'loss_total': 11.991100907325745, 'loss_family': 3.502018064260483, 'loss_genus': 4.36410266160965, 'loss_species': 4.1249799728393555, 'val_family_acc_top1': 0.057067812798471826, 'val_family_acc_top5': 0.16666666666666666, 'val_family_f1_macro': 0.010945453416495757, 'val_family_f1_weighted': 0.024032019634838725, 'val_genus_acc_top1': 0.014804202483285577, 'val_genus_acc_top5': 0.04656160458452722, 'val_genus_f1_macro': 0.006410982498006781, 'val_genus_f1_weighted': 0.008107022533323453, 'val_species_acc_top1': 0.007879656160458453, 'val_species_acc_top5': 0.03796561604584527, 'val_species_f1_macro': 0.01379178804568376, 'val_species_f1_weighted': 0.008113723250997325}
# {'k': 5, 'seed': 0, 'epoch': 3, 'loss_total': 9.909815311431885, 'loss_family': 2.6829638183116913, 'loss_genus': 3.576583832502365, 'loss_species': 3.650267720222473, 'val_family_acc_top1': 0.07067812798471824, 'val_family_acc_top5': 0.193170964660936, 'val_family_f1_macro': 0.011007106780077065, 'val_family_f1_weighted': 0.022069701425731395, 'val_genus_acc_top1': 0.01504297994269341, 'val_genus_acc_top5': 0.05300859598853868, 'val_genus_f1_macro': 0.007394133597514113, 'val_genus_f1_weighted': 0.006947218835429343, 'val_species_acc_top1': 0.011222540592168099, 'val_species_acc_top5': 0.03987583572110793, 'val_species_f1_macro': 0.018957439763610768, 'val_species_f1_weighted': 0.009016406386980924}
# {'k': 5, 'seed': 0, 'epoch': 4, 'loss_total': 8.085319995880127, 'loss_family': 2.0401556342840195, 'loss_genus': 2.9071685075759888, 'loss_species': 3.13799586892128, 'val_family_acc_top1': 0.08142311365807067, 'val_family_acc_top5': 0.2223018147086915, 'val_family_f1_macro': 0.02178762380711852, 'val_family_f1_weighted': 0.030100888167206744, 'val_genus_acc_top1': 0.027459407831900668, 'val_genus_acc_top5': 0.07067812798471824, 'val_genus_f1_macro': 0.014649946363606923, 'val_genus_f1_weighted': 0.013967566224067848, 'val_species_acc_top1': 0.01886341929321872, 'val_species_acc_top5': 0.058022922636103154, 'val_species_f1_macro': 0.04378843044297414, 'val_species_f1_weighted': 0.01697451127141404}
# {'k': 5, 'seed': 0, 'epoch': 5, 'loss_total': 6.40534371137619, 'loss_family': 1.5491510778665543, 'loss_genus': 2.2898153960704803, 'loss_species': 2.5663772523403168, 'val_family_acc_top1': 0.0964660936007641, 'val_family_acc_top5': 0.24355300859598855, 'val_family_f1_macro': 0.029054866853745157, 'val_family_f1_weighted': 0.045719525797524, 'val_genus_acc_top1': 0.038204393505253106, 'val_genus_acc_top5': 0.0883476599808978, 'val_genus_f1_macro': 0.026474679143784652, 'val_genus_f1_weighted': 0.022254510043947552, 'val_species_acc_top1': 0.02029608404966571, 'val_species_acc_top5': 0.07617000955109837, 'val_species_f1_macro': 0.04784720802166942, 'val_species_f1_weighted': 0.017400677216793444}
# {'k': 5, 'seed': 1, 'epoch': 1, 'loss_total': 13.964138150215149, 'loss_family': 4.257111042737961, 'loss_genus': 5.114151060581207, 'loss_species': 4.5928762555122375, 'val_family_acc_top1': 0.04250238777459408, 'val_family_acc_top5': 0.13705826170009552, 'val_family_f1_macro': 0.010380077905948096, 'val_family_f1_weighted': 0.020657530333526092, 'val_genus_acc_top1': 0.010267430754536771, 'val_genus_acc_top5': 0.03199617956064948, 'val_genus_f1_macro': 0.003868154667579824, 'val_genus_f1_weighted': 0.004349018554379719, 'val_species_acc_top1': 0.008118433619866285, 'val_species_acc_top5': 0.05157593123209169, 'val_species_f1_macro': 0.0008015027879181529, 'val_species_f1_weighted': 0.014245641428262679}
# {'k': 5, 'seed': 1, 'epoch': 2, 'loss_total': 11.778485774993896, 'loss_family': 3.361568570137024, 'loss_genus': 4.29966139793396, 'loss_species': 4.117255628108978, 'val_family_acc_top1': 0.05778414517669532, 'val_family_acc_top5': 0.17048710601719197, 'val_family_f1_macro': 0.011896933982970042, 'val_family_f1_weighted': 0.025540304255127287, 'val_genus_acc_top1': 0.018385864374403055, 'val_genus_acc_top5': 0.05300859598853868, 'val_genus_f1_macro': 0.0062474361206584636, 'val_genus_f1_weighted': 0.008319161968575827, 'val_species_acc_top1': 0.009312320916905445, 'val_species_acc_top5': 0.06709646609360076, 'val_species_f1_macro': 0.008685241866184624, 'val_species_f1_weighted': 0.013309022254926552}
# {'k': 5, 'seed': 1, 'epoch': 3, 'loss_total': 9.766595840454102, 'loss_family': 2.589551627635956, 'loss_genus': 3.530797094106674, 'loss_species': 3.6462469696998596, 'val_family_acc_top1': 0.07115568290353391, 'val_family_acc_top5': 0.1998567335243553, 'val_family_f1_macro': 0.01291131174864096, 'val_family_f1_weighted': 0.02558239422763118, 'val_genus_acc_top1': 0.02029608404966571, 'val_genus_acc_top5': 0.05682903533906399, 'val_genus_f1_macro': 0.007550929420431275, 'val_genus_f1_weighted': 0.007345147802264324, 'val_species_acc_top1': 0.0164756446991404, 'val_species_acc_top5': 0.06614135625596944, 'val_species_f1_macro': 0.02210559282403238, 'val_species_f1_weighted': 0.021131986789484056}
# {'k': 5, 'seed': 1, 'epoch': 4, 'loss_total': 8.00859159231186, 'loss_family': 1.9887668788433075, 'loss_genus': 2.8713952004909515, 'loss_species': 3.1484295427799225, 'val_family_acc_top1': 0.0778414517669532, 'val_family_acc_top5': 0.20845272206303725, 'val_family_f1_macro': 0.016301370505834748, 'val_family_f1_weighted': 0.030168290001618973, 'val_genus_acc_top1': 0.02387774594078319, 'val_genus_acc_top5': 0.06494746895893028, 'val_genus_f1_macro': 0.011364233192939192, 'val_genus_f1_weighted': 0.010133861063303945, 'val_species_acc_top1': 0.019579751671442217, 'val_species_acc_top5': 0.08572110792741165, 'val_species_f1_macro': 0.031893772870063085, 'val_species_f1_weighted': 0.01918181878615413}
# {'k': 5, 'seed': 1, 'epoch': 5, 'loss_total': 6.3662585616111755, 'loss_family': 1.512220874428749, 'loss_genus': 2.2809004485607147, 'loss_species': 2.5731372237205505, 'val_family_acc_top1': 0.08739255014326648, 'val_family_acc_top5': 0.22206303724928367, 'val_family_f1_macro': 0.02167591528403007, 'val_family_f1_weighted': 0.04194003565576834, 'val_genus_acc_top1': 0.029369627507163324, 'val_genus_acc_top5': 0.08333333333333333, 'val_genus_f1_macro': 0.019742862194709318, 'val_genus_f1_weighted': 0.01594700500691501, 'val_species_acc_top1': 0.022922636103151862, 'val_species_acc_top5': 0.10195797516714422, 'val_species_f1_macro': 0.045273107713034444, 'val_species_f1_weighted': 0.02242453859367325}
# {'k': 5, 'seed': 2, 'epoch': 1, 'loss_total': 14.012049317359924, 'loss_family': 4.289525866508484, 'loss_genus': 5.147416174411774, 'loss_species': 4.575107455253601, 'val_family_acc_top1': 0.03127984718242598, 'val_family_acc_top5': 0.10434574976122254, 'val_family_f1_macro': 0.009855236269018708, 'val_family_f1_weighted': 0.01948033594032969, 'val_genus_acc_top1': 0.009073543457497613, 'val_genus_acc_top5': 0.033428844317096466, 'val_genus_f1_macro': 0.002749555254288814, 'val_genus_f1_weighted': 0.0031359820815724535, 'val_species_acc_top1': 0.04465138490926457, 'val_species_acc_top5': 0.13705826170009552, 'val_species_f1_macro': 0.0022212728651185214, 'val_species_f1_weighted': 0.08367559349188895}
# {'k': 5, 'seed': 2, 'epoch': 2, 'loss_total': 11.784011006355286, 'loss_family': 3.369347184896469, 'loss_genus': 4.329803645610809, 'loss_species': 4.08486008644104, 'val_family_acc_top1': 0.058500477554918814, 'val_family_acc_top5': 0.1556829035339064, 'val_family_f1_macro': 0.012773344640838666, 'val_family_f1_weighted': 0.023484154848280817, 'val_genus_acc_top1': 0.014087870105062083, 'val_genus_acc_top5': 0.04894937917860554, 'val_genus_f1_macro': 0.004106004212922004, 'val_genus_f1_weighted': 0.004822907707966741, 'val_species_acc_top1': 0.029847182425978988, 'val_species_acc_top5': 0.11246418338108882, 'val_species_f1_macro': 0.009343036688630887, 'val_species_f1_weighted': 0.05265350738553339}
# {'k': 5, 'seed': 2, 'epoch': 3, 'loss_total': 9.75505256652832, 'loss_family': 2.5806362628936768, 'loss_genus': 3.555045783519745, 'loss_species': 3.619370549917221, 'val_family_acc_top1': 0.07378223495702006, 'val_family_acc_top5': 0.17836676217765043, 'val_family_f1_macro': 0.015233686973715365, 'val_family_f1_weighted': 0.027403376198768818, 'val_genus_acc_top1': 0.019579751671442217, 'val_genus_acc_top5': 0.055873925501432664, 'val_genus_f1_macro': 0.008348661490423896, 'val_genus_f1_weighted': 0.006588805548277733, 'val_species_acc_top1': 0.013849092645654251, 'val_species_acc_top5': 0.07282712511938873, 'val_species_f1_macro': 0.012402188833532984, 'val_species_f1_weighted': 0.018297929243909248}
# {'k': 5, 'seed': 2, 'epoch': 4, 'loss_total': 8.006726562976837, 'loss_family': 2.00553497672081, 'loss_genus': 2.889892131090164, 'loss_species': 3.1112994849681854, 'val_family_acc_top1': 0.08166189111747851, 'val_family_acc_top5': 0.20152817574021012, 'val_family_f1_macro': 0.017435082856034224, 'val_family_f1_weighted': 0.03125394975954481, 'val_genus_acc_top1': 0.023400191021967526, 'val_genus_acc_top5': 0.07163323782234957, 'val_genus_f1_macro': 0.013051705742009631, 'val_genus_f1_weighted': 0.007696910433419826, 'val_species_acc_top1': 0.01623686723973257, 'val_species_acc_top5': 0.06685768863419293, 'val_species_f1_macro': 0.03176922327033283, 'val_species_f1_weighted': 0.01783171161125089}
# {'k': 5, 'seed': 2, 'epoch': 5, 'loss_total': 6.4267120361328125, 'loss_family': 1.548761710524559, 'loss_genus': 2.316137433052063, 'loss_species': 2.561812847852707, 'val_family_acc_top1': 0.09264565425023878, 'val_family_acc_top5': 0.22206303724928367, 'val_family_f1_macro': 0.024870381830464944, 'val_family_f1_weighted': 0.041675998352308306, 'val_genus_acc_top1': 0.03414517669531996, 'val_genus_acc_top5': 0.08954154727793696, 'val_genus_f1_macro': 0.02200550206520698, 'val_genus_f1_weighted': 0.0161744998519838, 'val_species_acc_top1': 0.01790830945558739, 'val_species_acc_top5': 0.08739255014326648, 'val_species_f1_macro': 0.046560859542078205, 'val_species_f1_weighted': 0.01675254459435758}
# {'k': 10, 'seed': 0, 'epoch': 1, 'loss_total': 13.458690496591421, 'loss_family': 4.043147453894982, 'loss_genus': 4.931112839625432, 'loss_species': 4.484430276430571, 'val_family_acc_top1': 0.04727793696275072, 'val_family_acc_top5': 0.1669054441260745, 'val_family_f1_macro': 0.007760046644960197, 'val_family_f1_weighted': 0.01879787818071763, 'val_genus_acc_top1': 0.010983763132760267, 'val_genus_acc_top5': 0.04274116523400191, 'val_genus_f1_macro': 0.007753870646484897, 'val_genus_f1_weighted': 0.006062811371305843, 'val_species_acc_top1': 0.07282712511938873, 'val_species_acc_top5': 0.24713467048710602, 'val_species_f1_macro': 0.013664221288139515, 'val_species_f1_weighted': 0.13246324565566137}
# {'k': 10, 'seed': 0, 'epoch': 2, 'loss_total': 10.33362652705266, 'loss_family': 2.826252680558425, 'loss_genus': 3.7378800832308254, 'loss_species': 3.7694937082437368, 'val_family_acc_top1': 0.07115568290353391, 'val_family_acc_top5': 0.19675262655205347, 'val_family_f1_macro': 0.017289735805564362, 'val_family_f1_weighted': 0.02443866003329879, 'val_genus_acc_top1': 0.0164756446991404, 'val_genus_acc_top5': 0.053724928366762174, 'val_genus_f1_macro': 0.010068789213673084, 'val_genus_f1_weighted': 0.006353271246986494, 'val_species_acc_top1': 0.05826170009551098, 'val_species_acc_top5': 0.20057306590257878, 'val_species_f1_macro': 0.02915454994999436, 'val_species_f1_weighted': 0.10114617349298277}
# {'k': 10, 'seed': 0, 'epoch': 3, 'loss_total': 7.7431440353393555, 'loss_family': 1.9801558256149292, 'loss_genus': 2.7577757835388184, 'loss_species': 3.005212435355553, 'val_family_acc_top1': 0.09336198662846228, 'val_family_acc_top5': 0.22874880611270296, 'val_family_f1_macro': 0.026090853656861413, 'val_family_f1_weighted': 0.043888363049657986, 'val_genus_acc_top1': 0.034861509073543455, 'val_genus_acc_top5': 0.083810888252149, 'val_genus_f1_macro': 0.01771279630870982, 'val_genus_f1_weighted': 0.01794294721242925, 'val_species_acc_top1': 0.05659025787965616, 'val_species_acc_top5': 0.20534861509073543, 'val_species_f1_macro': 0.03678676316226168, 'val_species_f1_weighted': 0.0897494380854778}
# {'k': 10, 'seed': 0, 'epoch': 4, 'loss_total': 5.548578225649321, 'loss_family': 1.3808241073901837, 'loss_genus': 1.9706395130891066, 'loss_species': 2.1971145684902487, 'val_family_acc_top1': 0.11413562559694365, 'val_family_acc_top5': 0.25262655205348616, 'val_family_f1_macro': 0.03645446781240195, 'val_family_f1_weighted': 0.06308416321671102, 'val_genus_acc_top1': 0.0494269340974212, 'val_genus_acc_top5': 0.10434574976122254, 'val_genus_f1_macro': 0.027528330050472335, 'val_genus_f1_weighted': 0.027173297834079742, 'val_species_acc_top1': 0.06757402101241643, 'val_species_acc_top5': 0.28247373447946517, 'val_species_f1_macro': 0.04510346908331464, 'val_species_f1_weighted': 0.10804583844475829}
# {'k': 10, 'seed': 0, 'epoch': 5, 'loss_total': 3.72088569861192, 'loss_family': 0.8911500848256625, 'loss_genus': 1.3134655677355254, 'loss_species': 1.5162700964854314, 'val_family_acc_top1': 0.13228271251193888, 'val_family_acc_top5': 0.26743075453677173, 'val_family_f1_macro': 0.05893064533488166, 'val_family_f1_weighted': 0.08674055021469955, 'val_genus_acc_top1': 0.06566380133715377, 'val_genus_acc_top5': 0.11318051575931232, 'val_genus_f1_macro': 0.03563080232798407, 'val_genus_f1_weighted': 0.04237947597454852, 'val_species_acc_top1': 0.05253104106972302, 'val_species_acc_top5': 0.26528175740210125, 'val_species_f1_macro': 0.04950246670980848, 'val_species_f1_weighted': 0.07761976322211299}
# {'k': 10, 'seed': 1, 'epoch': 1, 'loss_total': 13.464530504666842, 'loss_family': 4.0547963472513056, 'loss_genus': 4.935632962446946, 'loss_species': 4.474101213308481, 'val_family_acc_top1': 0.0561127029608405, 'val_family_acc_top5': 0.15663801337153774, 'val_family_f1_macro': 0.009366777565496734, 'val_family_f1_weighted': 0.021800401656063253, 'val_genus_acc_top1': 0.01504297994269341, 'val_genus_acc_top5': 0.04202483285577841, 'val_genus_f1_macro': 0.007318936622295276, 'val_genus_f1_weighted': 0.007564260052321669, 'val_species_acc_top1': 0.06566380133715377, 'val_species_acc_top5': 0.23782234957020057, 'val_species_f1_macro': 0.009120811011393275, 'val_species_f1_weighted': 0.11750211465980746}
# {'k': 10, 'seed': 1, 'epoch': 2, 'loss_total': 10.291640868553749, 'loss_family': 2.8092947006225586, 'loss_genus': 3.736317671262301, 'loss_species': 3.746028643388015, 'val_family_acc_top1': 0.06852913085004776, 'val_family_acc_top5': 0.17908309455587393, 'val_family_f1_macro': 0.01708193635334822, 'val_family_f1_weighted': 0.02405827712738342, 'val_genus_acc_top1': 0.021967526265520534, 'val_genus_acc_top5': 0.06160458452722063, 'val_genus_f1_macro': 0.01003582564661647, 'val_genus_f1_weighted': 0.011855929521297343, 'val_species_acc_top1': 0.016714422158548233, 'val_species_acc_top5': 0.08142311365807067, 'val_species_f1_macro': 0.011252757046748961, 'val_species_f1_weighted': 0.024134559025511006}
# {'k': 10, 'seed': 1, 'epoch': 3, 'loss_total': 7.643075759594257, 'loss_family': 1.960501762536856, 'loss_genus': 2.731058964362511, 'loss_species': 2.9515150693746715, 'val_family_acc_top1': 0.08978032473734479, 'val_family_acc_top5': 0.21561604584527222, 'val_family_f1_macro': 0.02425724110113094, 'val_family_f1_weighted': 0.04389522706284344, 'val_genus_acc_top1': 0.041786055396370585, 'val_genus_acc_top5': 0.0890639923591213, 'val_genus_f1_macro': 0.02011745137111354, 'val_genus_f1_weighted': 0.02241331455147505, 'val_species_acc_top1': 0.02268385864374403, 'val_species_acc_top5': 0.0883476599808978, 'val_species_f1_macro': 0.02608291481926013, 'val_species_f1_weighted': 0.02610501620296437}
# {'k': 10, 'seed': 1, 'epoch': 4, 'loss_total': 5.410008283761831, 'loss_family': 1.3491473656434279, 'loss_genus': 1.9029670220154982, 'loss_species': 2.1578939236127415, 'val_family_acc_top1': 0.11461318051575932, 'val_family_acc_top5': 0.24832855778414517, 'val_family_f1_macro': 0.059335758991814126, 'val_family_f1_weighted': 0.07077857674658002, 'val_genus_acc_top1': 0.05563514804202483, 'val_genus_acc_top5': 0.10004775549188157, 'val_genus_f1_macro': 0.02855492771716305, 'val_genus_f1_weighted': 0.03381537381258533, 'val_species_acc_top1': 0.02363896848137536, 'val_species_acc_top5': 0.134909264565425, 'val_species_f1_macro': 0.0462313041226168, 'val_species_f1_weighted': 0.022768968969370584}
# {'k': 10, 'seed': 1, 'epoch': 5, 'loss_total': 3.616867780685425, 'loss_family': 0.8805302473214957, 'loss_genus': 1.2620317477446337, 'loss_species': 1.4743058314690223, 'val_family_acc_top1': 0.1346704871060172, 'val_family_acc_top5': 0.26313276026743077, 'val_family_f1_macro': 0.07613558336531265, 'val_family_f1_weighted': 0.0926012418056787, 'val_genus_acc_top1': 0.06494746895893028, 'val_genus_acc_top5': 0.10577841451766953, 'val_genus_f1_macro': 0.037691049262681825, 'val_genus_f1_weighted': 0.043480936078013, 'val_species_acc_top1': 0.031757402101241644, 'val_species_acc_top5': 0.20415472779369628, 'val_species_f1_macro': 0.06760897015424654, 'val_species_f1_weighted': 0.03632927437091421}
# {'k': 10, 'seed': 2, 'epoch': 1, 'loss_total': 13.496361805842472, 'loss_family': 4.082958551553579, 'loss_genus': 4.933736581068772, 'loss_species': 4.4796666365403395, 'val_family_acc_top1': 0.055396370582617004, 'val_family_acc_top5': 0.15974212034383956, 'val_family_f1_macro': 0.012744025414025273, 'val_family_f1_weighted': 0.025724289396241832, 'val_genus_acc_top1': 0.012655205348615091, 'val_genus_acc_top5': 0.04321872015281757, 'val_genus_f1_macro': 0.0035676363803267904, 'val_genus_f1_weighted': 0.004956356897331882, 'val_species_acc_top1': 0.04011461318051576, 'val_species_acc_top5': 0.14637058261700095, 'val_species_f1_macro': 0.003091450327401956, 'val_species_f1_weighted': 0.07267796249552319}
# {'k': 10, 'seed': 2, 'epoch': 2, 'loss_total': 10.284187536973219, 'loss_family': 2.8101917596963735, 'loss_genus': 3.723624211091262, 'loss_species': 3.7503715661855845, 'val_family_acc_top1': 0.07951289398280802, 'val_family_acc_top5': 0.2125119388729704, 'val_family_f1_macro': 0.013703319224984845, 'val_family_f1_weighted': 0.030290746883080567, 'val_genus_acc_top1': 0.019102196752626553, 'val_genus_acc_top5': 0.05635148042024833, 'val_genus_f1_macro': 0.009326599542210308, 'val_genus_f1_weighted': 0.008218390563701786, 'val_species_acc_top1': 0.038204393505253106, 'val_species_acc_top5': 0.12082139446036294, 'val_species_f1_macro': 0.013300564065382253, 'val_species_f1_weighted': 0.0634249050599202}
# {'k': 10, 'seed': 2, 'epoch': 3, 'loss_total': 7.617649078369141, 'loss_family': 1.91972711453071, 'loss_genus': 2.720171781686636, 'loss_species': 2.977750007922833, 'val_family_acc_top1': 0.09694364851957975, 'val_family_acc_top5': 0.24498567335243554, 'val_family_f1_macro': 0.0346862267646152, 'val_family_f1_weighted': 0.04617331537393822, 'val_genus_acc_top1': 0.03844317096466093, 'val_genus_acc_top5': 0.09574976122254059, 'val_genus_f1_macro': 0.017638198605170314, 'val_genus_f1_weighted': 0.01708211584634459, 'val_species_acc_top1': 0.0725883476599809, 'val_species_acc_top5': 0.20749761222540591, 'val_species_f1_macro': 0.02391179406043459, 'val_species_f1_weighted': 0.11888599145031234}
# {'k': 10, 'seed': 2, 'epoch': 4, 'loss_total': 5.366661365215595, 'loss_family': 1.3252747242267315, 'loss_genus': 1.8879345472042377, 'loss_species': 2.153452020425063, 'val_family_acc_top1': 0.11843361986628462, 'val_family_acc_top5': 0.26743075453677173, 'val_family_f1_macro': 0.053342966981181496, 'val_family_f1_weighted': 0.06610096313160904, 'val_genus_acc_top1': 0.05778414517669532, 'val_genus_acc_top5': 0.10840496657115568, 'val_genus_f1_macro': 0.026482967225028138, 'val_genus_f1_weighted': 0.03275413157610476, 'val_species_acc_top1': 0.08524355300859598, 'val_species_acc_top5': 0.2502387774594078, 'val_species_f1_macro': 0.04703142781595594, 'val_species_f1_weighted': 0.13736490588800843}
# {'k': 10, 'seed': 2, 'epoch': 5, 'loss_total': 3.6541129992558408, 'loss_family': 0.8768482162402227, 'loss_genus': 1.267125624876756, 'loss_species': 1.5101392269134521, 'val_family_acc_top1': 0.1339541547277937, 'val_family_acc_top5': 0.276981852913085, 'val_family_f1_macro': 0.06359077232498074, 'val_family_f1_weighted': 0.08611377833886465, 'val_genus_acc_top1': 0.06876790830945559, 'val_genus_acc_top5': 0.11604584527220631, 'val_genus_f1_macro': 0.0328653317330741, 'val_genus_f1_weighted': 0.04156456232033109, 'val_species_acc_top1': 0.10506208213944604, 'val_species_acc_top5': 0.2810410697230181, 'val_species_f1_macro': 0.06472916110090035, 'val_species_f1_weighted': 0.1686896391760961}
# {'k': 20, 'seed': 0, 'epoch': 1, 'loss_total': 14.421382904052734, 'loss_family': 4.512209892272949, 'loss_genus': 5.361741065979004, 'loss_species': 4.547431945800781, 'val_family_acc_top1': 0.01002865329512894, 'val_family_acc_top5': 0.052292263610315186, 'val_family_f1_macro': 0.004795700201203789, 'val_family_f1_weighted': 0.008584796381630127, 'val_genus_acc_top1': 0.008357211079274117, 'val_genus_acc_top5': 0.03008595988538682, 'val_genus_f1_macro': 0.005358067222763696, 'val_genus_f1_weighted': 0.007251290296661821, 'val_species_acc_top1': 0.013610315186246419, 'val_species_acc_top5': 0.06876790830945559, 'val_species_f1_macro': 0.00039218085192503746, 'val_species_f1_weighted': 0.026389284207495662}
# {'k': 20, 'seed': 0, 'epoch': 2, 'loss_total': 13.45633602142334, 'loss_family': 4.191055774688721, 'loss_genus': 5.043974876403809, 'loss_species': 4.221304893493652, 'val_family_acc_top1': 0.013132760267430755, 'val_family_acc_top5': 0.0613658070678128, 'val_family_f1_macro': 0.006153972102456739, 'val_family_f1_weighted': 0.011911412749113257, 'val_genus_acc_top1': 0.008595988538681949, 'val_genus_acc_top5': 0.0329512893982808, 'val_genus_f1_macro': 0.006014816511647098, 'val_genus_f1_weighted': 0.007397827875151053, 'val_species_acc_top1': 0.033428844317096466, 'val_species_acc_top5': 0.14207258834765998, 'val_species_f1_macro': 0.0007885467686860604, 'val_species_f1_weighted': 0.06328345394774101}
# {'k': 20, 'seed': 0, 'epoch': 3, 'loss_total': 12.569599151611328, 'loss_family': 3.8948323726654053, 'loss_genus': 4.737758159637451, 'loss_species': 3.9370083808898926, 'val_family_acc_top1': 0.016714422158548233, 'val_family_acc_top5': 0.08070678127984718, 'val_family_f1_macro': 0.007253002956914193, 'val_family_f1_weighted': 0.01761531988537668, 'val_genus_acc_top1': 0.010506208213944603, 'val_genus_acc_top5': 0.035577841451766956, 'val_genus_f1_macro': 0.005299807703014339, 'val_genus_f1_weighted': 0.007840478870392232, 'val_species_acc_top1': 0.08213944603629417, 'val_species_acc_top5': 0.26313276026743077, 'val_species_f1_macro': 0.0016554692967754134, 'val_species_f1_weighted': 0.15019105317096726}
# {'k': 20, 'seed': 0, 'epoch': 4, 'loss_total': 11.633222579956055, 'loss_family': 3.5925381183624268, 'loss_genus': 4.445206642150879, 'loss_species': 3.595477819442749, 'val_family_acc_top1': 0.0164756446991404, 'val_family_acc_top5': 0.09527220630372493, 'val_family_f1_macro': 0.00671586963857624, 'val_family_f1_weighted': 0.016563246188309542, 'val_genus_acc_top1': 0.011938872970391595, 'val_genus_acc_top5': 0.04465138490926457, 'val_genus_f1_macro': 0.00424987513291823, 'val_genus_f1_weighted': 0.008405876958709198, 'val_species_acc_top1': 0.1556829035339064, 'val_species_acc_top5': 0.43242597898758356, 'val_species_f1_macro': 0.003099622066335517, 'val_species_f1_weighted': 0.26655979871635505}
# {'k': 20, 'seed': 0, 'epoch': 5, 'loss_total': 10.738048553466797, 'loss_family': 3.3052804470062256, 'loss_genus': 4.151001930236816, 'loss_species': 3.2817656993865967, 'val_family_acc_top1': 0.01886341929321872, 'val_family_acc_top5': 0.1227316141356256, 'val_family_f1_macro': 0.007094782381820026, 'val_family_f1_weighted': 0.018141962076867614, 'val_genus_acc_top1': 0.012893982808022923, 'val_genus_acc_top5': 0.051098376313276024, 'val_genus_f1_macro': 0.003966296848891755, 'val_genus_f1_weighted': 0.0074838784691044005, 'val_species_acc_top1': 0.2409264565425024, 'val_species_acc_top5': 0.6012416427889207, 'val_species_f1_macro': 0.004384326226919223, 'val_species_f1_weighted': 0.3834470847920435}
# {'k': 20, 'seed': 1, 'epoch': 1, 'loss_total': 14.45556640625, 'loss_family': 4.445040225982666, 'loss_genus': 5.240391731262207, 'loss_species': 4.7701334953308105, 'val_family_acc_top1': 0.00883476599808978, 'val_family_acc_top5': 0.05276981852913085, 'val_family_f1_macro': 0.004658009445906349, 'val_family_f1_weighted': 0.008950401391877166, 'val_genus_acc_top1': 0.0052531041069723014, 'val_genus_acc_top5': 0.03151862464183381, 'val_genus_f1_macro': 0.0026426606105027046, 'val_genus_f1_weighted': 0.004379018584439381, 'val_species_acc_top1': 0.0038204393505253103, 'val_species_acc_top5': 0.024594078319006684, 'val_species_f1_macro': 0.00041850145654088474, 'val_species_f1_weighted': 0.007161637409350784}
# {'k': 20, 'seed': 1, 'epoch': 2, 'loss_total': 13.503042221069336, 'loss_family': 4.125757217407227, 'loss_genus': 4.924689292907715, 'loss_species': 4.4525957107543945, 'val_family_acc_top1': 0.015520534861509073, 'val_family_acc_top5': 0.06160458452722063, 'val_family_f1_macro': 0.007502686567971327, 'val_family_f1_weighted': 0.014078128774405653, 'val_genus_acc_top1': 0.0059694364851957974, 'val_genus_acc_top5': 0.030802292263610316, 'val_genus_f1_macro': 0.002877512121748233, 'val_genus_f1_weighted': 0.004554865557410495, 'val_species_acc_top1': 0.009789875835721109, 'val_species_acc_top5': 0.05993314231136581, 'val_species_f1_macro': 0.0005461420209053265, 'val_species_f1_weighted': 0.018940831863945382}
# {'k': 20, 'seed': 1, 'epoch': 3, 'loss_total': 12.532186508178711, 'loss_family': 3.7722179889678955, 'loss_genus': 4.610845565795898, 'loss_species': 4.149123668670654, 'val_family_acc_top1': 0.018147086914995225, 'val_family_acc_top5': 0.0778414517669532, 'val_family_f1_macro': 0.00687594067762691, 'val_family_f1_weighted': 0.014916729923766548, 'val_genus_acc_top1': 0.007640878701050621, 'val_genus_acc_top5': 0.03247373447946514, 'val_genus_f1_macro': 0.0024357222305790792, 'val_genus_f1_weighted': 0.005814741988495217, 'val_species_acc_top1': 0.029608404966571154, 'val_species_acc_top5': 0.1361031518624642, 'val_species_f1_macro': 0.0011091520859028473, 'val_species_f1_weighted': 0.05660062049997459}
# {'k': 20, 'seed': 1, 'epoch': 4, 'loss_total': 11.639959335327148, 'loss_family': 3.492271661758423, 'loss_genus': 4.302547931671143, 'loss_species': 3.845139741897583, 'val_family_acc_top1': 0.027936962750716332, 'val_family_acc_top5': 0.09718242597898759, 'val_family_f1_macro': 0.008340167268680516, 'val_family_f1_weighted': 0.02028876572918765, 'val_genus_acc_top1': 0.011222540592168099, 'val_genus_acc_top5': 0.03772683858643744, 'val_genus_f1_macro': 0.0032426087934492, 'val_genus_f1_weighted': 0.00731324130993686, 'val_species_acc_top1': 0.06303724928366762, 'val_species_acc_top5': 0.2502387774594078, 'val_species_f1_macro': 0.0018634040641759115, 'val_species_f1_weighted': 0.1171550325744433}
# {'k': 20, 'seed': 1, 'epoch': 5, 'loss_total': 10.61903190612793, 'loss_family': 3.134963035583496, 'loss_genus': 3.959164619445801, 'loss_species': 3.5249037742614746, 'val_family_acc_top1': 0.030563514804202482, 'val_family_acc_top5': 0.1174785100286533, 'val_family_f1_macro': 0.008738994447822487, 'val_family_f1_weighted': 0.01974738245074093, 'val_genus_acc_top1': 0.010744985673352435, 'val_genus_acc_top5': 0.04321872015281757, 'val_genus_f1_macro': 0.002721159473887653, 'val_genus_f1_weighted': 0.006044238443375156, 'val_species_acc_top1': 0.11127029608404966, 'val_species_acc_top5': 0.4052053486150907, 'val_species_f1_macro': 0.0029261133792201593, 'val_species_f1_weighted': 0.19749027990893805}
# {'k': 20, 'seed': 2, 'epoch': 1, 'loss_total': 14.47065544128418, 'loss_family': 4.417675495147705, 'loss_genus': 5.361143589019775, 'loss_species': 4.691836833953857, 'val_family_acc_top1': 0.011461318051575931, 'val_family_acc_top5': 0.05730659025787966, 'val_family_f1_macro': 0.004989508493508092, 'val_family_f1_weighted': 0.012133562425015475, 'val_genus_acc_top1': 0.004775549188156638, 'val_genus_acc_top5': 0.03462273161413563, 'val_genus_f1_macro': 0.0019984887076726627, 'val_genus_f1_weighted': 0.004112840442264964, 'val_species_acc_top1': 0.0054918815663801334, 'val_species_acc_top5': 0.03724928366762178, 'val_species_f1_macro': 0.0003051220488195278, 'val_species_f1_weighted': 0.009990846864056033}
# {'k': 20, 'seed': 2, 'epoch': 2, 'loss_total': 13.538366317749023, 'loss_family': 4.108503818511963, 'loss_genus': 5.054841995239258, 'loss_species': 4.375020980834961, 'val_family_acc_top1': 0.019102196752626553, 'val_family_acc_top5': 0.07020057306590258, 'val_family_f1_macro': 0.006787553892302468, 'val_family_f1_weighted': 0.020746606653992097, 'val_genus_acc_top1': 0.0057306590257879654, 'val_genus_acc_top5': 0.03677172874880611, 'val_genus_f1_macro': 0.0025730936552996104, 'val_genus_f1_weighted': 0.004590280340018897, 'val_species_acc_top1': 0.01886341929321872, 'val_species_acc_top5': 0.08094555873925502, 'val_species_f1_macro': 0.00047622321821294105, 'val_species_f1_weighted': 0.03606921467415643}
# {'k': 20, 'seed': 2, 'epoch': 3, 'loss_total': 12.627374649047852, 'loss_family': 3.8174355030059814, 'loss_genus': 4.764440536499023, 'loss_species': 4.045499324798584, 'val_family_acc_top1': 0.02268385864374403, 'val_family_acc_top5': 0.07999044890162368, 'val_family_f1_macro': 0.006491346357055173, 'val_family_f1_weighted': 0.02241376789146762, 'val_genus_acc_top1': 0.008595988538681949, 'val_genus_acc_top5': 0.038204393505253106, 'val_genus_f1_macro': 0.0034617733688608317, 'val_genus_f1_weighted': 0.005976515044332883, 'val_species_acc_top1': 0.047039159503342885, 'val_species_acc_top5': 0.16404011461318052, 'val_species_f1_macro': 0.0010042142218225564, 'val_species_f1_weighted': 0.08827925512364142}
# {'k': 20, 'seed': 2, 'epoch': 4, 'loss_total': 11.759665489196777, 'loss_family': 3.533817768096924, 'loss_genus': 4.479457378387451, 'loss_species': 3.7463905811309814, 'val_family_acc_top1': 0.028175740210124166, 'val_family_acc_top5': 0.09789875835721108, 'val_family_f1_macro': 0.006896093139195166, 'val_family_f1_weighted': 0.02493837844383591, 'val_genus_acc_top1': 0.010506208213944603, 'val_genus_acc_top5': 0.039159503342884434, 'val_genus_f1_macro': 0.004099997372641244, 'val_genus_f1_weighted': 0.006802803731349843, 'val_species_acc_top1': 0.08572110792741165, 'val_species_acc_top5': 0.29608404966571156, 'val_species_f1_macro': 0.0017506867034748927, 'val_species_f1_weighted': 0.15540451528823257}
# {'k': 20, 'seed': 2, 'epoch': 5, 'loss_total': 10.81435489654541, 'loss_family': 3.2225492000579834, 'loss_genus': 4.167967319488525, 'loss_species': 3.4238386154174805, 'val_family_acc_top1': 0.02913085004775549, 'val_family_acc_top5': 0.11127029608404966, 'val_family_f1_macro': 0.006331936835976444, 'val_family_f1_weighted': 0.023594683723136375, 'val_genus_acc_top1': 0.010744985673352435, 'val_genus_acc_top5': 0.04393505253104107, 'val_genus_f1_macro': 0.004194876067099361, 'val_genus_f1_weighted': 0.006522035670756393, 'val_species_acc_top1': 0.1356255969436485, 'val_species_acc_top5': 0.45391595033428844, 'val_species_f1_macro': 0.002569199251010839, 'val_species_f1_weighted': 0.23524050144603081}
# [{'k': 1,
#   'n_seeds': 3,
#   'species_acc_top1_mean': 0.007720471187519898,
#   'species_acc_top1_std': 0.0022596417648166806},
#  {'k': 5,
#   'n_seeds': 3,
#   'species_acc_top1_mean': 0.02037567653613499,
#   'species_acc_top1_std': 0.002047863790236964},
#  {'k': 10,
#   'n_seeds': 3,
#   'species_acc_top1_mean': 0.06311684177013689,
#   'species_acc_top1_std': 0.030848429578910957},
#  {'k': 20,
#   'n_seeds': 3,
#   'species_acc_top1_mean': 0.1626074498567335,
#   'species_acc_top1_std': 0.05626541433938808}]

# %%
from fish_ai.utils.run_logging import write_csv

write_csv(OUT_DIR / 'summary.csv', summary)
print('wrote:', OUT_DIR / 'summary.csv')
# Out:
# wrote: D:\Fish Codes\outputs\fewshot_taxonomy\summary.csv
